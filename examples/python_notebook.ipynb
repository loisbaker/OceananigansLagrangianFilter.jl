# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
ds = xr.open_dataset("periodic_geostrophic_adjustment_online.nc",decode_times=False)

# %%
fig, ax = plt.subplots(1,4, figsize=(15,3))
ds.T[:,10,:].plot(ax=ax[0], vmin=0, vmax=1, cmap="Spectral")
ds.T_Eulerian_filtered[:,10,:].plot(ax=ax[1], vmin=0, vmax=1, cmap="Spectral")
ds.T_Lagrangian_filtered[:,10,:].plot(ax=ax[2], vmin=0, vmax=1, cmap="Spectral")
ds.T_Lagrangian_filtered_at_mean[:,10,:].plot(ax=ax[3], vmin=0, vmax=1, cmap="Spectral")

# %%
ds.T_Eulerian_filtered[1,:,:].plot()
